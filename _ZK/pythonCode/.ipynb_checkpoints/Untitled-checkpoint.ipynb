# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def delta(e, L, a, h):
    return (3*L**2 - 4*a**2)*e / (12*h)

def P(delta, L, a, b, h):
    return 300000 * 4*b*h**3*delta / (a*(3*L**2 - 4*a**2))

# %%
L = 12
b = 3
h = 3
a = 4

d1 = delta(3.15e-3, L,a,h)

# %%
P1 = P(d1, L,a,b,h)

# %%
P1
# Out:
# 2126.25

# %%
print(1)
print(2)
# Out:
# 1
# 2

# %%
elist = [3.15, 2.61, 2.49, 1.92, 1.59, 1.27, 1.09, 0.873]
for e in elist:
    d_ = delta(e*1e-3, L,a,h)
    print(d_)
    print(P(d_, L,a,b,h))
    print('-----')
# Out:
# 0.0322
# 2126.25
# -----
# 0.02668
# 1761.75
# -----
# 0.025453333333333338
# 1680.7500000000002
# -----
# 0.019626666666666667
# 1296.0
# -----
# 0.01625333333333333
# 1073.2499999999998
# -----
# 0.012982222222222223
# 857.25
# -----
# 0.011142222222222223
# 735.7500000000001
# -----
# 0.008924
# 589.275
# -----

# %%
sd =37.5
pd = 45000
q = 125

# %%
a = np.sqrt(pd/np.pi/q)
d = sd - 2*a
d
# Out:
# 16.090510606166745

# %%
(1.05**20-1)/0.05
# Out:
# 33.06595410288844
